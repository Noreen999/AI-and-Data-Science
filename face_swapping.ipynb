# %% [markdown]
# <a href="https://colab.research.google.com/github/Noreen999/AI-and-Data-Science/blob/main/face_swapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If you want to use the latest version remove `!git checkout 312208a41102ba86d2454ae8efc9d3f0b786a6e7`**

# %%
# !git clone https://github.com/FurkanGozukara/roop
# %cd roop
#Tested and updated 23 August 2023 commit
#!git checkout da1ef285f1d43bd0cc8b9cdb9a0f80f7ae793a97
# !pip install onnxruntime-gpu && pip install -r requirements.txt
# !pip install onnxruntime-gpu --upgrade
# !apt-get update --yes
# !apt install nvidia-cuda-toolkit --yes
# !pip install opennsfw2 keras --upgrade
# Out:
# fatal: destination path 'roop' already exists and is not an empty directory.
# /content/roop/roop
# ...
# ERROR: Operation cancelled by user
# ...
#   Using cached onnxruntime_gpu-1.18.0-cp310-cp310-manylinux_2_28_x86_64.whl (199.8 MB)
# ...
#   Attempting uninstall: onnxruntime-gpu
#     Found existing installation: onnxruntime-gpu 1.15.1
#     Uninstalling onnxruntime-gpu-1.15.1:
#       Successfully uninstalled onnxruntime-gpu-1.15.1
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %% [markdown]
# **You will see processing message at the end of below printed messages e.g. Processing:  43% 136/318 00:38<00:24, 7.47frame/s**
#
# **Make sure to upload root roop folder not inside the sub roop folder and don't forget to change image and video file names**
#
# **1 is best quality big video size, 100 worst quality low video size**

# %%
# %cd "/content/roop"
# !python run.py -s "/content/images.jpeg" -t "/content/video.mp4" -o "face_changed_video_v2.mp4" --keep-frames --keep-fps --temp-frame-quality 1 --output-video-quality 1 --execution-provider cuda

# %% [markdown]
# **Below code will do also face restoration to improve quality significantly but it will take longer**

# %%
# %cd "/content/roop"
# !python run.py -s "/content/images.jpeg" -t "/content/video.mp4" -o "face_restored_video3.mp4" --keep-frames --keep-fps --temp-frame-quality 1 --output-video-quality 1 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# /content/roop
# 2024-06-04 18:27:14.893877: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 18:27:14.893942: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 18:27:14.898593: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

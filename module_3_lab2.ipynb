# %% [markdown]
# <a href="https://colab.research.google.com/github/Noreen999/AI-and-Data-Science/blob/main/module_3_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #pandas Group by

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}


# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
df.groupby('Name')

# %%
print(df.groupby('Name').groups)
# Out:
# {'Abhi': [7], 'Anuj': [1, 5], 'Gaurav': [4], 'Jai': [0, 2], 'Princi': [3, 6]}

# %%
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
print(df.groupby('Age').groups)
# Out:
# {22: [2], 24: [1], 27: [0, 6], 32: [3, 7], 33: [4], 36: [5]}

# %%
df.groupby(['Name']).sum()
# Out:
# <ipython-input-38-5f38b951ad8c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Name']).sum()
#         Age
# Name
# Abhi     32
# Anuj     60
# Gaurav   33
# Jai      49
# Princi   59

# %%
df.groupby(['Name'], sort = False).sum()
# Out:
# <ipython-input-39-3d4dbd60104e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Name'], sort = False).sum()
#         Age
# Name
# Jai      49
# Anuj     60
# Princi   59
# Gaurav   33
# Abhi     32

# %%
grp = df.groupby('Name')
grp.get_group('Jai')
# Out:
#   Name  Age    Address Qualification
# 0  Jai   27     Nagpur           Msc
# 2  Jai   22  Allahabad           MCA

# %%
grp1 = df.groupby(['Name', 'Qualification'])
import numpy as np
grp1.aggregate(np.sum)
# Out:
# <ipython-input-45-90655d748216>:3: FutureWarning: The operation <function sum at 0x7977837076d0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   grp1.aggregate(np.sum)
#                       Age
# Name   Qualification
# Abhi   MA              32
# Anuj   B.com           36
#        MA              24
# Gaurav B.Tech          33
# Jai    MCA             22
#        Msc             27
# Princi Msc             27
#        Phd             32

# %%
import pandas as pd

# %%
import pandas as pd
# create dataframe

data= {'company':['goog','goog','msft','msft','fb','fb'],
      'person':['sam','charlie','amy','vanessa','carl','sarah'],
       'sales':[200,210,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   company   person  sales
# 0    goog      sam    200
# 1    goog  charlie    210
# 2    msft      amy    340
# 3    msft  vanessa    124
# 4      fb     carl    243
# 5      fb    sarah    350

# %%
df.shape
# Out:
# (6, 3)

# %%
df.groupby('company')

# %%
by_comp=df.groupby('company')

# %% [markdown]
# ##mean

# %%
by_comp.mean()
# Out:
# <ipython-input-21-15ce3fbdee9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.mean()
#          sales    new
# company
# fb       296.5  593.0
# goog     205.0  410.0
# msft     232.0  464.0

# %%
df.groupby('person').mean()
# Out:
# <ipython-input-63-84c1c16fa3ba>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('person').mean()
#          sales
# person
# amy      340.0
# carl     243.0
# charlie  210.0
# sam      200.0
# sarah    350.0
# vanessa  124.0

# %%
df.groupby('sales').mean()
# Out:
# <ipython-input-9-1c44b8c0cd12>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sales').mean()
# Empty DataFrame
# Columns: []
# Index: [124, 200, 210, 243, 340, 350]

# %%
df['new'] = df['sales'] + df['sales']

df
# Out:
#   company   person  sales  new
# 0    goog      sam    200  400
# 1    goog  charlie    210  420
# 2    msft      amy    340  680
# 3    msft  vanessa    124  248
# 4      fb     carl    243  486
# 5      fb    sarah    350  700

# %%
df.groupby('company').mean()
# Out:
# <ipython-input-15-68a802e890b6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('company').mean()
#          sales
# company
# fb       296.5
# goog     205.0
# msft     232.0

# %%
df.groupby('sales').mean()
# Out:
# <ipython-input-14-1c44b8c0cd12>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sales').mean()
# Empty DataFrame
# Columns: []
# Index: [124, 200, 210, 243, 340, 350]

# %% [markdown]
# ##median,mode,sum

# %%
df.groupby('sales').median()
# Out:
# <ipython-input-12-91b9958f1647>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sales').median()
# Empty DataFrame
# Columns: []
# Index: [124, 200, 210, 243, 340, 350]

# %% [markdown]
# #Standard deviation

# %%
by_comp.min()
# Out:
#           person  sales  new
# company
# fb          carl    243  486
# goog     charlie    200  400
# msft         amy    124  248

# %%
by_comp.std()
# Out:
# <ipython-input-23-795bdc0ea79d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.std()
#               sales         new
# company
# fb        75.660426  151.320851
# goog       7.071068   14.142136
# msft     152.735065  305.470129

# %%
by_comp.max()
# Out:
#           person  sales  new
# company
# fb         sarah    350  700
# goog         sam    210  420
# msft     vanessa    340  680

# %%
by_comp.count()
# Out:
#          person  sales
# company
# fb            2      2
# goog          2      2
# msft          2      2

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/sample_data/california_housing_train.csv')
df=pd.DataFrame(data)

# %%
df.head(12)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
#
# ...

# %%
df.describe()
# Out:
#             sales        new
# count    6.000000    6.00000
# mean   244.500000  489.00000
# std     87.113145  174.22629
# min    124.000000  248.00000
# 25%    202.500000  405.00000
# 50%    226.500000  453.00000
# 75%    315.750000  631.50000
# max    350.000000  700.00000

# %%
by_comp.describe().transpose()
# Out:
# company              fb        goog        msft
# sales count    2.000000    2.000000    2.000000
#       mean   296.500000  205.000000  232.000000
#       std     75.660426    7.071068  152.735065
#       min    243.000000  200.000000  124.000000
#       25%    269.750000  202.500000  178.000000
#       50%    296.500000  205.000000  232.000000
#       75%    323.250000  207.500000  286.000000
#       max    350.000000  210.000000  340.000000
# new   count    2.000000    2.000000    2.000000
#       mean   593.000000  410.000000  464.000000
#       std    151.320851   14.142136  305.470129
#       min    486.000000  400.000000  248.000000
#       25%    539.500000  405.000000  356.000000
#       50%    593.000000  410.000000  464.000000
#       75%    646.500000  415.000000  572.000000
#       max    700.000000  420.000000  680.000000

# %%
by_comp.describe().transpose()['fb']
# Out:
# sales  count      2.000000
#        mean     296.500000
#        std       75.660426
#        min      243.000000
#        25%      269.750000
#        50%      296.500000
#        75%      323.250000
#        max      350.000000
# new    count      2.000000
#        mean     593.000000
#        std      151.320851
#        min      486.000000
#        25%      539.500000
#        50%      593.000000
#        75%      646.500000
#        max      700.000000
# Name: fb, dtype: float64

# %% [markdown]
# #Merging joining and concatenating
